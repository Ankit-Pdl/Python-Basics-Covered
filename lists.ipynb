# %%
student1 = "Anamika"
student2 = "Abhishek"
student3 = "Riya"
student4 = "Suman"

# %%
#lists name[] basic syntax
students = ["Anamika","Abhishek","Riya","Suman"] 
print(students[0])
print(students[1])
print(students[2])
print(students[3])
students.sort()
print(students)
print(students[1:2])
# Out:
# Anamika
# Abhishek
# Riya
# Suman
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       4 print(students[1])
#       5 print(students[2])
#       6 print(students[3])
#       7 students.sort()
# ----> 8 print(students())
#       9 print(students[1:2])
#
# TypeError: 'list' object is not callable

# %%
nums = [10,20,30,40,60]
#nums[?] = 30??? 
# comment down
